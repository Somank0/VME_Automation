// %%
TFile *f = new TFile("VME_TDC_QDC_output_20250724_112140_2hr_Converted_data.root");
f->ls();
// Out:
// TFile**		VME_TDC_QDC_output_20250724_112140_2hr_Converted_data.root
//  TFile*		VME_TDC_QDC_output_20250724_112140_2hr_Converted_data.root
//   KEY: TTree	TDC_tree;1	TDC Valid Data
//   KEY: TTree	QDC_tree;1	QDC Valid Data

// %%
TDC_tree->Print();
QDC_tree->Print();
// Out:
// ******************************************************************************
// *Tree    :TDC_tree  : TDC Valid Data                                         *
// *Entries :     1530 : Total =          120688 bytes  File  Size =      10295 *
// *        :          : Tree compression factor =  12.04                       *
// ******************************************************************************
// *Br    0 :Raw_data  : Raw_data/i                                             *
// *Entries :     1530 : Total  Size=       6696 bytes  File Size  =       2360 *
// *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.63     *
// *............................................................................*
// *Br    1 :ch_0      : ch_0/i                                                 *
// *Entries :     1530 : Total  Size=       6676 bytes  File Size  =       1269 *
// *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.88     *
// ...
